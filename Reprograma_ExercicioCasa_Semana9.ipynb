# %% [markdown]
# <a href="https://colab.research.google.com/github/angelasc/on29-python-s09-pandas-numpy-I/blob/main/Reprograma_ExercicioCasa_Semana9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('data_sample_DF.csv', sep=';', encoding='latin-1', on_bad_lines='skip')
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2020/10/19  2100 UTC                             0.0
# 1      2022/03/24  0900 UTC                             0.0
# 2      2020/03/02  0600 UTC                             0.0
# 3      2021/07/12  1900 UTC                             0.0
# 4      2022/07/22  0900 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2021/08/10  0400 UTC                             0.0
# 99996  2020/07/07  2200 UTC                             0.0
# 99997  2020/01/25  1600 UTC                             0.2
# 99998  2021/05/26  0100 UTC                             0.0
# 99999  2021/01/14  0100 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  903.6
# 1                                                  887.7
# 2                                                  897.1
# ...

# %% [markdown]
# Calcular a média da temperatura da amostra

# %% [markdown]
# Retirar nulos da coluna 'RADIACAO GLOBAL (Kj/m2)'

# %%
df = df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])
df.shape
# Out:
# (53228, 27)

# %% [markdown]
# Copiar o dataframe reduzindo para 3 colunas (a sua escolha) e 1000 linhas (aleatórias)

# %%
df_reduzido = df[['Data', 'ESTACAO', 'PRECIPITAO TOTAL. HORARIO (mm)', ]]
df_reduzido.sample(1000)
# Out:
#              Data             ESTACAO  PRECIPITAO TOTAL. HORARIO (mm)
# 1430   2020/05/31          BRAZLANDIA                             0.0
# 44891  2022/05/14  PARANOA (COOPA-DF)                             0.0
# 74787  2021/06/25  PARANOA (COOPA-DF)                             0.0
# 52139  2020/03/25   GAMA (PONTE ALTA)                             3.2
# 3973   2021/06/10     AGUAS EMENDADAS                             0.0
# ...           ...                 ...                             ...
# 86284  2022/03/01            BRASILIA                             0.0
# 33622  2020/01/24          BRAZLANDIA                             0.6
# 70856  2021/11/02  PARANOA (COOPA-DF)                             0.0
# 43362  2021/06/13            BRASILIA                             0.0
# 8697   2020/02/29          BRAZLANDIA                             0.0
#
# [1000 rows x 3 columns]

# %% [markdown]
# Normalizar coluna (qualquer uma)

# %%
df_normalizado = df.copy()
coluna = 'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'
df_normalizado[coluna] = (df_normalizado[coluna] - df_normalizado[coluna].min()) / (df_normalizado[coluna].max() - df_normalizado[coluna].min())
df_normalizado[coluna]
# Out:
# 0        0.518841
# 3        0.655072
# 7        0.666667
# 8        0.649275
# 9        0.669565
#            ...
# 99987    0.539130
# 99990    0.649275
# 99992    0.626087
# 99994    0.539130
# 99997    0.565217
# Name: TEMPERATURA DO AR - BULBO SECO. HORARIA (C), Length: 53228, dtype: float64

# %% [markdown]
# Pesquisar sobre outras formas de processamento de dados além das vistas em sala de aula
