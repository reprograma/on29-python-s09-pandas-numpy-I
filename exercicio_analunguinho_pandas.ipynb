# %% [markdown]
# <a href="https://colab.research.google.com/github/Anutchax/on29-python-s09-pandas-numpy-I/blob/main/exercicio_analunguinho_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_AM.csv', sep=';')

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 2      2020/12/04  0000 UTC                             0.0
# 4      2021/10/15  2100 UTC                             NaN
# 6      2022/09/15  1600 UTC                             0.0
# 9      2022/01/25  1800 UTC                             NaN
# 12     2022/05/11  1000 UTC                             0.0
# ...           ...       ...                             ...
# 99988  2022/01/05  0300 UTC                             NaN
# 99989  2022/01/04  1300 UTC                             0.0
# 99990  2022/02/28  1800 UTC                             0.0
# 99996  2020/03/22  1300 UTC                             0.0
# 99997  2021/10/16  2100 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 2                                                 1002.7
# 4                                                 1002.1
# 6                                                 1002.2
# ...

# %%
# Calcular a média da temperatura da amostra

# %%
df[['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)']].mean()
# Out:
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)    26.847517
# dtype: float64

# %%
df.loc[:, 'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'].mean()
# Out:
# 26.847517101884055

# %%
# Retirar nulos da coluna 'RADIACAO GLOBAL (Kj/m2)'

# %%
df = df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])

df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 2      2020/12/04  0000 UTC                             0.0
# 4      2021/10/15  2100 UTC                             NaN
# 6      2022/09/15  1600 UTC                             0.0
# 9      2022/01/25  1800 UTC                             NaN
# 12     2022/05/11  1000 UTC                             0.0
# ...           ...       ...                             ...
# 99988  2022/01/05  0300 UTC                             NaN
# 99989  2022/01/04  1300 UTC                             0.0
# 99990  2022/02/28  1800 UTC                             0.0
# 99996  2020/03/22  1300 UTC                             0.0
# 99997  2021/10/16  2100 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 2                                                 1002.7
# 4                                                 1002.1
# 6                                                 1002.2
# ...

# %%
# Copiar o dataframe reduzindo para 3 colunas (a sua escolha) e 1000 linhas (aleatórias)

# %%
df_reduzido = df[['PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)', 'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)', 'ESTACAO']].sample(1000)

df_reduzido
# Out:
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 44014                                             1000.3
# 38914                                             1005.7
# 30979                                              995.0
# 62816                                             1004.9
# 18673                                             1007.4
# ...                                                  ...
# 84445                                             1008.5
# 58502                                             1008.7
# 16651                                             1003.8
# 70012                                             1003.2
# 50308                                             1001.9
#
#        TEMPERATURA DO AR - BULBO SECO. HORARIA (C)             ESTACAO
# 44014                                         31.5  S. G. DA CACHOEIRA
# 38914                                         30.8           PARINTINS
# ...
