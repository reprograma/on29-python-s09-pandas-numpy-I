# %% [markdown]
# <a href="https://colab.research.google.com/github/PamReprograma/on29-python-s09-pandas-numpy-I/blob/main/Para_casa_reprograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_MG.csv', sep = ';')

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2022/09/08  2200 UTC                             0.0
# 1      2021/01/26  1100 UTC                             0.0
# 2      2021/11/24  2100 UTC                             0.0
# 3      2021/07/25  1800 UTC                             0.0
# 4      2020/07/16  0700 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2021/02/15  1500 UTC                             0.0
# 99996  2021/03/25  1400 UTC                             0.0
# 99997  2020/05/23  1300 UTC                             0.0
# 99998  2021/10/18  2100 UTC                             NaN
# 99999  2022/10/16  0400 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  909.4
# 1                                                  926.5
# 2                                                  924.5
# ...

# %%
df.shape
# Out:
# (100000, 27)

# %%
df.describe()
# Out:
#        PRECIPITAO TOTAL. HORARIO (mm)  \
# count                    86183.000000
# mean                         0.159468
# std                          1.261362
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                         45.400000
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# count                                       89353.000000
# mean                                          930.620117
# std                                            32.034012
# min                                           839.500000
# 25%                                           909.500000
# 50%                                           927.500000
# 75%                                           954.600000
# max                                          1005.100000
#
#        PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# ...

# %%
df[['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)','TEMPERATURA DO PONTO DE ORVALHO (C)','TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)','TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)','TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)','TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)']]
# Out:
#        TEMPERATURA DO AR - BULBO SECO. HORARIA (C)  \
# 0                                             22.8
# 1                                             22.5
# 2                                             27.6
# 3                                             27.8
# 4                                             16.1
# ...                                            ...
# 99995                                         25.6
# 99996                                         27.4
# 99997                                         21.1
# 99998                                          NaN
# 99999                                         20.7
#
#        TEMPERATURA DO PONTO DE ORVALHO (C)  \
# 0                                      8.6
# 1                                     19.6
# 2                                     11.4
# 3                                      4.6
# 4                                     14.6
# ...                                    ...
# ...

# %%
df[['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)','TEMPERATURA DO PONTO DE ORVALHO (C)','TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)','TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)','TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)','TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)']].isnull().sum()
# Out:
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)        10637
# TEMPERATURA DO PONTO DE ORVALHO (C)                12280
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)          10767
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)          10767
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)    12420
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)    12461
# dtype: int64

# %%
df.dropna(subset=['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)','TEMPERATURA DO PONTO DE ORVALHO (C)','TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)','TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)','TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)','TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)'])
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2022/09/08  2200 UTC                             0.0
# 1      2021/01/26  1100 UTC                             0.0
# 2      2021/11/24  2100 UTC                             0.0
# 3      2021/07/25  1800 UTC                             0.0
# 4      2020/07/16  0700 UTC                             0.0
# ...           ...       ...                             ...
# 99994  2021/01/12  2200 UTC                             0.0
# 99995  2021/02/15  1500 UTC                             0.0
# 99996  2021/03/25  1400 UTC                             0.0
# 99997  2020/05/23  1300 UTC                             0.0
# 99999  2022/10/16  0400 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  909.4
# 1                                                  926.5
# 2                                                  924.5
# ...

# %%
# Tentei deletar os valores NaN e nulos(87516 rows × 27 columns), para comparar a média inicial da função describe(), com a função média sem os valores nulos.
# Mas percebi que deu os mesmo valores, a função describe já retira os valores nulos e NaN antes de fazer a média.

# %%
df[['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)','TEMPERATURA DO PONTO DE ORVALHO (C)','TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)','TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)','TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)','TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)']].mean()
# Out:
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)        21.860721
# TEMPERATURA DO PONTO DE ORVALHO (C)                15.158186
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)          22.606231
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)          21.158992
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)    15.741360
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)    14.605210
# dtype: float64

# %%
# Retirar os valores nulos da coluna Radiação: (is null: 49748)

# %%
df['RADIACAO GLOBAL (Kj/m2)'].isnull().sum()
# Out:
# 49748

# %%
df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 1      2021/01/26  1100 UTC                             0.0
# 2      2021/11/24  2100 UTC                             0.0
# 3      2021/07/25  1800 UTC                             0.0
# 5      2022/09/29  1400 UTC                             0.0
# 6      2021/04/30  1900 UTC                             0.0
# ...           ...       ...                             ...
# 99993  2020/02/08  1300 UTC                             0.0
# 99994  2021/01/12  2200 UTC                             0.0
# 99995  2021/02/15  1500 UTC                             0.0
# 99996  2021/03/25  1400 UTC                             0.0
# 99997  2020/05/23  1300 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 1                                                  926.5
# 2                                                  924.5
# 3                                                  929.2
# ...

# %%
df = df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 1      2021/01/26  1100 UTC                             0.0
# 2      2021/11/24  2100 UTC                             0.0
# 3      2021/07/25  1800 UTC                             0.0
# 5      2022/09/29  1400 UTC                             0.0
# 6      2021/04/30  1900 UTC                             0.0
# ...           ...       ...                             ...
# 99993  2020/02/08  1300 UTC                             0.0
# 99994  2021/01/12  2200 UTC                             0.0
# 99995  2021/02/15  1500 UTC                             0.0
# 99996  2021/03/25  1400 UTC                             0.0
# 99997  2020/05/23  1300 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 1                                                  926.5
# 2                                                  924.5
# 3                                                  929.2
# ...

# %%
# Df depois da retirada das colunas nulas e NaN da radiação(50252 rows × 27 columns).

# %%
# Reduzir 3 colunas a 1000 linhas:

# %%
df_menor = df[['LATITUDE','LONGITUDE',	'ALTITUDE']].sample(1000)

# %%
# Coloquei o drop igual a false, porque acha melhor ter o id antigo, caso  perca algum dado, fica mais fácil para localizar.

# %%
df_menor = df_menor.reset_index(drop=False)

# %%
df_menor
# Out:
#      index   LATITUDE  LONGITUDE  ALTITUDE
# 0    16984 -15.524167 -46.435556    894.00
# 1    19271 -18.231052 -43.648269   1359.25
# 2     1451 -20.715000 -44.864444   1025.00
# 3     3033 -18.786944 -42.943056    852.68
# 4    48445 -19.875278 -47.434167    913.12
# ..     ...        ...        ...       ...
# 995  66425 -17.892840 -41.515423    467.17
# 996  97432 -15.085958 -44.016036    454.00
# 997  89135 -19.710000 -47.961944    778.00
# 998  43440 -18.996684 -46.985935    978.11
# 999  10233 -21.105000 -42.375833    282.79
#
# [1000 rows x 4 columns]

# %%
# Normalização:

# %%
df.min(numeric_only = True)
# Out:
# PRECIPITAO TOTAL. HORARIO (mm)                             0.000000
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)    840.700000
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          841.000000
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         840.700000
# RADIACAO GLOBAL (Kj/m2)                                    0.000000
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)                0.000000
# TEMPERATURA DO PONTO DE ORVALHO (C)                       -9.500000
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                  1.400000
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                 -0.900000
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)           -9.100000
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)           -9.800000
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                   7.000000
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                   7.000000
# UMIDADE RELATIVA DO AR. HORARIA (%)                        7.000000
# ...

# %%
df.max(numeric_only=True)
# Out:
# PRECIPITAO TOTAL. HORARIO (mm)                             45.400000
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)    1005.100000
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          1005.300000
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         1005.100000
# RADIACAO GLOBAL (Kj/m2)                                  5492.900000
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)                41.300000
# TEMPERATURA DO PONTO DE ORVALHO (C)                        25.700000
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                  42.600000
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                  40.300000
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)            27.500000
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)            25.400000
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                  100.000000
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                  100.000000
# UMIDADE RELATIVA DO AR. HORARIA (%)                       100.000000
# ...

# %%
maior_amplitude = df.max(numeric_only=True) - df.min(numeric_only=True)

# %%
maior_amplitude
# Out:
# PRECIPITAO TOTAL. HORARIO (mm)                             45.400000
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)     164.400000
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           164.300000
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          164.400000
# RADIACAO GLOBAL (Kj/m2)                                  5492.900000
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)                41.300000
# TEMPERATURA DO PONTO DE ORVALHO (C)                        35.200000
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                  41.200000
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                  41.200000
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)            36.600000
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)            35.200000
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                   93.000000
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                   93.000000
# UMIDADE RELATIVA DO AR. HORARIA (%)                        93.000000
# ...

# %%
normalizacao = (df['VENTO. DIREAO HORARIA (gr) ((gr))'] - df['VENTO. DIREAO HORARIA (gr) ((gr))'].min())/(df['VENTO. DIREAO HORARIA (gr) ((gr))'].max() - df['VENTO. DIREAO HORARIA (gr) ((gr))'].min())

# %%
normalizacao
# Out:
# 1        0.114206
# 2        0.292479
# 3        0.949861
# 5        0.401114
# 6        0.103064
#            ...
# 99993    0.089136
# 99994    0.699164
# 99995    0.905292
# 99996    0.303621
# 99997    0.476323
# Name: VENTO. DIREAO HORARIA (gr) ((gr)), Length: 50252, dtype: float64

# %%
# Ao revisar, vi que você pediu a temperatura geral:

# %%
df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'].count()
# Out:
# 50250

# %%
df['TEMPERATURA DO PONTO DE ORVALHO (C)'].count()
# Out:
# 49387

# %%
media_temperaturas = (df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'].sum() + df['TEMPERATURA DO PONTO DE ORVALHO (C)'].sum())/(50250 + 49387)

# %%
media_temperaturas
# Out:
# 19.660707367744912
