# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanndaPaula/on29-python-s09-pandas-numpy-I/blob/main/exercicios/para-casa%20/exercicio_casa/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_PE.csv', sep=';' , encoding='latin-1', on_bad_lines='skip')

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/04/26  1700 UTC                             NaN
# 1      2022/03/02  0900 UTC                             NaN
# 2      2020/01/30  1200 UTC                             0.0
# 3      2020/09/12  0600 UTC                             0.0
# 4      2020/08/16  1100 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/08/22  2200 UTC                             NaN
# 99996  2020/05/04  0800 UTC                             0.0
# 99997  2020/01/15  0500 UTC                             0.0
# 99998  2021/06/16  0400 UTC                             NaN
# 99999  2022/10/07  2200 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  971.9
# 1                                                    NaN
# 2                                                  958.8
# ...

# %%
df [['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)','TEMPERATURA DO PONTO DE ORVALHO (C)']].mean()
# Out:
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)    25.283303
# TEMPERATURA DO PONTO DE ORVALHO (C)            17.382828
# dtype: float64

# %%
df['RADIACAO GLOBAL (Kj/m2)'].fillna(df['RADIACAO GLOBAL (Kj/m2)'].mean())
# Out:
# 0        1652.500000
# 1        1443.837365
# 2        2278.000000
# 3        1443.837365
# 4        1372.800000
#             ...
# 99995    1443.837365
# 99996    1443.837365
# 99997    1443.837365
# 99998    1443.837365
# 99999    1443.837365
# Name: RADIACAO GLOBAL (Kj/m2), Length: 100000, dtype: float64

# %%
df [['Data','Hora UTC','VENTO. VELOCIDADE HORARIA (m/s)']].sample(1000)
# Out:
#              Data  Hora UTC  VENTO. VELOCIDADE HORARIA (m/s)
# 64487  2022/08/19  2300 UTC                              NaN
# 30236  2020/04/22  1200 UTC                              1.5
# 49985  2020/12/23  0300 UTC                              0.3
# 78346  2021/12/20  1500 UTC                              NaN
# 68145  2022/04/25  2000 UTC                              NaN
# ...           ...       ...                              ...
# 38962  2021/12/28  0700 UTC                              NaN
# 28070  2020/06/08  1700 UTC                              5.1
# 18990  2022/02/21  1800 UTC                              NaN
# 13202  2022/10/01  2300 UTC                              NaN
# 26947  2021/02/22  0300 UTC                              3.3
#
# [1000 rows x 3 columns]

# %%
df_normalizado = df.copy()
