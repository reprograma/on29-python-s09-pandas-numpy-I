# %% [markdown]
# <a href="https://colab.research.google.com/github/lorena-vieira/on29-python-s09-pandas-numpy-I/blob/main/exercicios/para-casa/exercicio_casa_semana9_Lorena.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_PE.csv', sep=";")

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/04/26  1700 UTC                             NaN
# 1      2022/03/02  0900 UTC                             NaN
# 2      2020/01/30  1200 UTC                             0.0
# 3      2020/09/12  0600 UTC                             0.0
# 4      2020/08/16  1100 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/08/22  2200 UTC                             NaN
# 99996  2020/05/04  0800 UTC                             0.0
# 99997  2020/01/15  0500 UTC                             0.0
# 99998  2021/06/16  0400 UTC                             NaN
# 99999  2022/10/07  2200 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  971.9
# 1                                                    NaN
# 2                                                  958.8
# ...

# %%
df['TEMPERATURA DO PONTO DE ORVALHO (C)'].mean()
# Out:
# 17.382828031396755

# %%
df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/04/26  1700 UTC                             NaN
# 2      2020/01/30  1200 UTC                             0.0
# 4      2020/08/16  1100 UTC                             0.0
# 6      2022/05/18  1900 UTC                             0.0
# 7      2022/07/13  1600 UTC                             1.4
# ...           ...       ...                             ...
# 99983  2020/05/05  1000 UTC                             0.0
# 99984  2021/08/11  1200 UTC                            10.6
# 99985  2021/10/20  2000 UTC                             0.0
# 99988  2021/10/06  0900 UTC                             0.0
# 99993  2020/05/02  1800 UTC                             NaN
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  971.9
# 2                                                  958.8
# 4                                                  978.8
# ...

# %%
df_reduzido = df[['PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)', 'UMIDADE RELATIVA DO AR. HORARIA (%)', 'ALTITUDE']].sample(1000)

# %%
df_reduzido
# Out:
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 9565                                                 NaN
# 87669                                              977.2
# 33693                                              961.4
# 37725                                              994.5
# 42325                                              928.4
# ...                                                  ...
# 70431                                                NaN
# 4529                                               921.0
# 95103                                                NaN
# 24466                                              971.5
# 15040                                              961.7
#
#        UMIDADE RELATIVA DO AR. HORARIA (%)  ALTITUDE
# 9565                                   NaN    457.85
# 87669                                 56.0    372.72
# 33693                                 74.0    447.00
# 37725                                 80.0    164.01
# ...

# %%
coluna = 'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'
df[coluna] = (df[coluna] - df[coluna].min())/(df[coluna].max() - df[coluna].min())

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/04/26  1700 UTC                             NaN
# 1      2022/03/02  0900 UTC                             NaN
# 2      2020/01/30  1200 UTC                             0.0
# 3      2020/09/12  0600 UTC                             0.0
# 4      2020/08/16  1100 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/08/22  2200 UTC                             NaN
# 99996  2020/05/04  0800 UTC                             0.0
# 99997  2020/01/15  0500 UTC                             0.0
# 99998  2021/06/16  0400 UTC                             NaN
# 99999  2022/10/07  2200 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  971.9
# 1                                                    NaN
# 2                                                  958.8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   Data                                                   100000 non-null  object
#  1   Hora UTC                                               100000 non-null  object
#  2   PRECIPITAO TOTAL. HORARIO (mm)                         54658 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  63938 non-null   float64
#  4   PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        63816 non-null   float64
#  5   PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       63816 non-null   float64
#  6   RADIACAO GLOBAL (Kj/m2)                                37209 non-null   float64
#  7   TEMPERATURA DO AR - BULBO SECO. HORARIA (C)            64131 non-null   float64
# ...
