# %%
import pandas as pd

# %%
df = pd.read_csv("data_sample_MG.csv", sep= ";")

# %%
df.head()
# Out:
#          Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0  2022/09/08  2200 UTC                             0.0
# 1  2021/01/26  1100 UTC                             0.0
# 2  2021/11/24  2100 UTC                             0.0
# 3  2021/07/25  1800 UTC                             0.0
# 4  2020/07/16  0700 UTC                             0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                              909.4
# 1                                              926.5
# 2                                              924.5
# 3                                              929.2
# 4                                              928.6
#
#    PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            909.4
# 1                                            926.5
# 2                                            924.5
# 3                                            930.1
# ...

# %% [markdown]
# #calcular a média da temperatura da amostra

# %%
media_temp = df['TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)'].mean()

# %%
print(media_temp)
# Out:
# 22.60623087871079

# %% [markdown]
# #retirar nulos da coluna 'RADIACAO GLOBAL (Kj/m2)'

# %%
df['RADIACAO GLOBAL (Kj/m2)'].isnull().sum()
# Out:
# 49748

# %%
df_radiacao = df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])

# %%
df_radiacao['RADIACAO GLOBAL (Kj/m2)'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #copiar o dataframe reduzindo para 3 colunas (a sua escolha) e 1000 linhas (aleatórias)

# %%
df_menor = df[['RADIACAO GLOBAL (Kj/m2)', 'PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)', 'REGIAO']].sample(1000)

# %%
df_menor.head()
# Out:
#        RADIACAO GLOBAL (Kj/m2)  \
# 54119                    207.5
# 84160                   2666.3
# 71505                      NaN
# 37677                    350.4
# 81286                      NaN
#
#        PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB) REGIAO
# 54119                                            919.7     SE
# 84160                                            928.6     SE
# 71505                                            946.8     SE
# 37677                                            930.3     SE
# 81286                                              NaN     SE

# %%
df_menor.shape
# Out:
# (1000, 3)
