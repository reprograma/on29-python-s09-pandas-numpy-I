# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_PB.csv', sep=';')

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2020/01/22  0100 UTC                             NaN
# 1      2020/01/07  0000 UTC                             0.0
# 2      2020/12/30  2200 UTC                             0.0
# 3      2020/04/23  0100 UTC                             NaN
# 4      2020/02/07  2300 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/04/03  2100 UTC                             0.0
# 99996  2022/05/13  1200 UTC                             NaN
# 99997  2021/05/30  0400 UTC                             0.0
# 99998  2022/10/06  0600 UTC                             NaN
# 99999  2022/05/26  0500 UTC                             NaN
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  945.3
# 1                                                  948.7
# 2                                                  981.6
# ...

# %%
df.describe()
# Out:
#        PRECIPITAO TOTAL. HORARIO (mm)  \
# count                    61468.000000
# mean                         0.123180
# std                          1.234058
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                        138.200000
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# count                                       68585.000000
# mean                                          969.312546
# std                                            21.472012
# min                                           937.300000
# 25%                                           949.300000
# 50%                                           967.400000
# 75%                                           985.600000
# max                                          1014.900000
#
#        PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# ...

# %%
df[['TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)','TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)']].describe()
# Out:
#        TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)  \
# count                               35346.000000
# mean                                   28.231608
# std                                     3.921716
# min                                    14.000000
# 25%                                    25.300000
# 50%                                    28.500000
# 75%                                    31.100000
# max                                    39.500000
#
#        TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)
# count                               35346.000000
# mean                                   26.607891
# std                                     3.724501
# min                                    13.400000
# 25%                                    23.800000
# 50%                                    26.700000
# 75%                                    29.300000
# max                                    37.600000

# %%
df[['TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)','TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)']].mean()
# Out:
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)    25.986531
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)    24.779219
# dtype: float64

# %%
df = df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])

# %%
df.shape
# Out:
# (35405, 27)

# %%
df_normalizado = df.copy()

coluna = "TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)"

df_normalizado[coluna] = (df_normalizado[coluna] - df_normalizado[coluna].min()) / (df_normalizado[coluna].max() - df_normalizado[coluna].min())

df_normalizado[coluna]
# Out:
# 5        0.556863
# 6        0.764706
# 18       0.458824
# 21       0.643137
# 23       0.756863
#            ...
# 99988    0.584314
# 99989    0.701961
# 99991    0.313725
# 99995    0.556863
# 99997    0.219608
# Name: TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C), Length: 35405, dtype: float64

# %%
df[['LATITUDE','LONGITUDE','ALTITUDE']]
# Out:
#        LATITUDE  LONGITUDE  ALTITUDE
# 5     -7.165409 -34.815627     33.50
# 6     -7.318472 -38.140833    292.00
# 18    -7.894444 -37.124722    606.39
# 21    -7.894444 -37.124722    606.39
# 23    -7.079722 -37.272778    263.66
# ...         ...        ...       ...
# 99988 -6.975451 -35.718128    573.45
# 99989 -7.079722 -37.272778    263.66
# 99991 -7.894444 -37.124722    606.39
# 99995 -7.318472 -38.140833    292.00
# 99997 -6.975451 -35.718128    573.45
#
# [35405 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['LATITUDE'].plot(kind='hist', bins=20, title='LATITUDE')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['LONGITUDE'].plot(kind='hist', bins=20, title='LONGITUDE')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df_excluir_colunas = df.drop (['LATITUDE','LONGITUDE','ALTITUDE'], axis = 1)

# %%
df_excluir_colunas.describe()
# Out:
#        PRECIPITAO TOTAL. HORARIO (mm)  \
# count                    31342.000000
# mean                         0.113177
# std                          1.356077
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                        138.200000
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# count                                       35404.000000
# mean                                          972.898633
# std                                            20.874590
# min                                           937.300000
# 25%                                           951.300000
# 50%                                           979.100000
# 75%                                           986.200000
# max                                          1014.900000
#
#        PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# ...

# %%
df.select_dtypes(include='object')
# Out:
#              Data  Hora UTC REGIAO  UF      ESTACAO CODIGO (WMO)  \
# 5      2020/06/30  1200 UTC     NE  PB  JOAO PESSOA         A320
# 6      2020/01/14  2100 UTC     NE  PB   ITAPORANGA         A373
# 18     2020/10/11  1100 UTC     NE  PB     MONTEIRO         A334
# 21     2022/04/23  1600 UTC     NE  PB     MONTEIRO         A334
# 23     2022/12/30  1500 UTC     NE  PB        PATOS         A321
# ...           ...       ...    ...  ..          ...          ...
# 99988  2020/02/22  1600 UTC     NE  PB        AREIA         A310
# 99989  2020/04/20  2000 UTC     NE  PB        PATOS         A321
# 99991  2020/04/18  0900 UTC     NE  PB     MONTEIRO         A334
# 99995  2020/04/03  2100 UTC     NE  PB   ITAPORANGA         A373
# 99997  2021/05/30  0400 UTC     NE  PB        AREIA         A310
#
#       DATA DE FUNDACAO
# 5             21/07/07
# 6             03/11/17
# 18            22/08/07
# 21            22/08/07
# 23            21/07/07
# ...                ...
# ...

# %%
df.isnull().sum()
# Out:
# Data                                                        0
# Hora UTC                                                    0
# PRECIPITAO TOTAL. HORARIO (mm)                           4063
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)       1
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)            59
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)           59
# RADIACAO GLOBAL (Kj/m2)                                     0
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)                 0
# TEMPERATURA DO PONTO DE ORVALHO (C)                      2790
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                  59
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                  59
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)          2843
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)          2845
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 2842
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 2844
# ...
