# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_GO.csv', sep= ';' )

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2022/07/04  1100 UTC                             0.0
# 1      2020/06/07  0700 UTC                             NaN
# 2      2021/04/05  1200 UTC                             0.0
# 3      2022/03/10  1700 UTC                             0.0
# 4      2021/09/28  1500 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2022/07/12  1600 UTC                             0.0
# 99996  2022/02/17  0500 UTC                             1.4
# 99997  2022/08/14  2000 UTC                             0.0
# 99998  2021/06/14  1900 UTC                             0.0
# 99999  2022/08/20  1800 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  992.4
# 1                                                    NaN
# 2                                                  940.4
# ...

# %%
df_limpeza = df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])

# %%
df_limpeza
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2022/07/04  1100 UTC                             0.0
# 2      2021/04/05  1200 UTC                             0.0
# 3      2022/03/10  1700 UTC                             0.0
# 4      2021/09/28  1500 UTC                             0.0
# 6      2022/01/01  0400 UTC                             0.0
# ...           ...       ...                             ...
# 99994  2021/03/22  1500 UTC                             0.0
# 99995  2022/07/12  1600 UTC                             0.0
# 99997  2022/08/14  2000 UTC                             0.0
# 99998  2021/06/14  1900 UTC                             0.0
# 99999  2022/08/20  1800 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  992.4
# 2                                                  940.4
# 3                                                  968.6
# ...

# %%
mt = df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'].mean()

# %%
mt
# Out:
# 23.794327181466265

# %%
selecao_c = ['Data', 'ESTACAO', 'UMIDADE RELATIVA DO AR. HORARIA (%)']
df_selecao = df[selecao_c]

# %%
df_selecao
# Out:
#              Data                 ESTACAO  UMIDADE RELATIVA DO AR. HORARIA (%)
# 0      2022/07/04  SAO MIGUEL DO ARAGUAIA                                 63.0
# 1      2020/06/07               RIO VERDE                                  NaN
# 2      2021/04/05                   JATAI                                 70.0
# 3      2022/03/10               PORANGATU                                 55.0
# 4      2021/09/28   MONTE ALEGRE DE GOIAS                                 25.0
# ...           ...                     ...                                  ...
# 99995  2022/07/12                 PARAUNA                                 33.0
# 99996  2022/02/17              CRISTALINA                                 84.0
# 99997  2022/08/14                   IPORA                                 17.0
# 99998  2021/06/14                 PARAUNA                                 50.0
# 99999  2022/08/20               PORANGATU                                 20.0
#
# ...

# %%
df_div = df_selecao.sample(n=1000, random_state=1)

# %%
df_div
# Out:
#              Data                ESTACAO  UMIDADE RELATIVA DO AR. HORARIA (%)
# 43660  2022/04/28                  JATAI                                 85.0
# 87278  2022/10/24                GOIANIA                                 91.0
# 14317  2020/12/28                GOIANIA                                 93.0
# 81932  2020/06/08                CATALAO                                 56.0
# 95321  2021/09/07               MINEIROS                                  NaN
# ...           ...                    ...                                  ...
# 29559  2021/06/03  ALTO PARAISO DE GOIAS                                 43.0
# 96320  2021/09/10              RIO VERDE                                  NaN
# 38431  2021/12/16              ARAGARCAS                                 72.0
# 48756  2022/06/27              ITUMBIARA                                 55.0
# 9993   2020/06/08               MINEIROS                                 84.0
#
# [1000 rows x 3 columns]
