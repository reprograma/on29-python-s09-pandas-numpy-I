# %% [markdown]
# <a href="https://colab.research.google.com/github/Josyce2/on29-python-s09-pandas-numpy-I/blob/main/exercicios/para-casa/Exercico_aula_9_reprograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_CE.csv',sep=';',encoding='latin-1', on_bad_lines='skip')

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/05/10  1600 UTC                             NaN
# 1      2022/01/06  0500 UTC                             NaN
# 2      2020/12/30  2000 UTC                             NaN
# 3      2022/10/15  0800 UTC                             NaN
# 4      2021/04/03  1600 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/04/25  2200 UTC                             NaN
# 99996  2021/01/15  0200 UTC                             NaN
# 99997  2022/12/16  0400 UTC                             0.0
# 99998  2022/08/12  1500 UTC                             0.0
# 99999  2022/07/15  1900 UTC                             NaN
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'].mean()
# Out:
# 26.98861154446178

# %%
df[['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)','TEMPERATURA DO PONTO DE ORVALHO (C)']].mean()
# Out:
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)    26.988612
# TEMPERATURA DO PONTO DE ORVALHO (C)            19.416759
# dtype: float64

# %%
df['RADIACAO GLOBAL (Kj/m2)'].fillna(df['RADIACAO GLOBAL (Kj/m2)'].mean())
# Out:
# 0        1268.325421
# 1        1268.325421
# 2        1268.325421
# 3        1268.325421
# 4        3132.500000
#             ...
# 99995    1268.325421
# 99996    1268.325421
# 99997       0.000000
# 99998    3134.900000
# 99999    1268.325421
# Name: RADIACAO GLOBAL (Kj/m2), Length: 100000, dtype: float64

# %%
df[['TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)' , 'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)' , 'TEMPERATURA DO PONTO DE ORVALHO (C)']].sample(1000)
# Out:
#        TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)  \
# 71                                          33.3
# 27237                                       27.1
# 17115                                       28.0
# 70880                                       25.8
# 24223                                       22.6
# ...                                          ...
# 53990                                        NaN
# 48820                                        NaN
# 51030                                        NaN
# 86600                                       23.8
# 31529                                        NaN
#
#        TEMPERATURA DO AR - BULBO SECO. HORARIA (C)  \
# 71                                            33.1
# 27237                                         26.8
# 17115                                         27.5
# 70880                                         25.3
# 24223                                         22.2
# ...                                            ...
# ...

# %%
df_normalizado = df.copy()

coluna = 'TEMPERATURA DO PONTO DE ORVALHO (C)'

df_normalizado[coluna] = (df_normalizado[coluna] - df_normalizado[coluna].min()) / (df_normalizado[coluna].max() - df_normalizado[coluna].min())

df_normalizado[coluna]
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4        0.691710
#            ...
# 99995         NaN
# 99996         NaN
# 99997    0.655440
# 99998    0.668394
# 99999         NaN
# Name: TEMPERATURA DO PONTO DE ORVALHO (C), Length: 100000, dtype: float64

# %%
df = df.drop_duplicates()
df.shape
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/05/10  1600 UTC                             NaN
# 1      2022/01/06  0500 UTC                             NaN
# 2      2020/12/30  2000 UTC                             NaN
# 3      2022/10/15  0800 UTC                             NaN
# 4      2021/04/03  1600 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/04/25  2200 UTC                             NaN
# 99996  2021/01/15  0200 UTC                             NaN
# 99997  2022/12/16  0400 UTC                             0.0
# 99998  2022/08/12  1500 UTC                             0.0
# 99999  2022/07/15  1900 UTC                             NaN
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# ...
