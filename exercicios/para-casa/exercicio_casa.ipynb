# %% [markdown]
# <a href="https://colab.research.google.com/github/IsabelaMeyce/on29-python-s09-pandas-numpy-I/blob/main/exercicios/para-casa/exercicio_casa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_PE.csv', sep= ';')

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/04/26  1700 UTC                             NaN
# 1      2022/03/02  0900 UTC                             NaN
# 2      2020/01/30  1200 UTC                             0.0
# 3      2020/09/12  0600 UTC                             0.0
# 4      2020/08/16  1100 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/08/22  2200 UTC                             NaN
# 99996  2020/05/04  0800 UTC                             0.0
# 99997  2020/01/15  0500 UTC                             0.0
# 99998  2021/06/16  0400 UTC                             NaN
# 99999  2022/10/07  2200 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  971.9
# 1                                                    NaN
# 2                                                  958.8
# ...

# %%
df[['PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)','PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)','PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)']].mean(numeric_only=True)
# Out:
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)    965.106392
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          965.393530
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         964.873040
# dtype: float64

# %%
df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/04/26  1700 UTC                             NaN
# 2      2020/01/30  1200 UTC                             0.0
# 4      2020/08/16  1100 UTC                             0.0
# 6      2022/05/18  1900 UTC                             0.0
# 7      2022/07/13  1600 UTC                             1.4
# ...           ...       ...                             ...
# 99983  2020/05/05  1000 UTC                             0.0
# 99984  2021/08/11  1200 UTC                            10.6
# 99985  2021/10/20  2000 UTC                             0.0
# 99988  2021/10/06  0900 UTC                             0.0
# 99993  2020/05/02  1800 UTC                             NaN
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  971.9
# 2                                                  958.8
# 4                                                  978.8
# ...

# %%
df.head(1000)
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0    2021/04/26  1700 UTC                             NaN
# 1    2022/03/02  0900 UTC                             NaN
# 2    2020/01/30  1200 UTC                             0.0
# 3    2020/09/12  0600 UTC                             0.0
# 4    2020/08/16  1100 UTC                             0.0
# ..          ...       ...                             ...
# 995  2021/09/26  2300 UTC                             NaN
# 996  2021/05/29  1700 UTC                             0.0
# 997  2021/06/25  0800 UTC                             0.0
# 998  2021/05/05  0500 UTC                             0.0
# 999  2021/10/24  1300 UTC                             0.0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                971.9
# 1                                                  NaN
# 2                                                958.8
# ...

# %%
df.head(3)
# Out:
#          Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0  2021/04/26  1700 UTC                             NaN
# 1  2022/03/02  0900 UTC                             NaN
# 2  2020/01/30  1200 UTC                             0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                              971.9
# 1                                                NaN
# 2                                              958.8
#
#    PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            972.9
# 1                                              NaN
# 2                                            958.8
#
#    PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (Kj/m2)  \
# 0                                             971.9                   1652.5
# 1                                               NaN                      NaN
# ...
