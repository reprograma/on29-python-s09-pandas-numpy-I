# %% [markdown]
# <a href="https://colab.research.google.com/github/kaarimaa/on29-python-s09-pandas-numpy-I/blob/main/exercicios/para-casa/exercicio_de_casa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_SP.csv' , sep=';' , encoding='latin-1', on_bad_lines='skip')
#Importando os dados necessários com a separação no formato ideal

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/07/31  1100 UTC                             0.0
# 1      2020/01/16  0800 UTC                             0.0
# 2      2021/08/25  1900 UTC                             0.0
# 3      2021/08/02  1600 UTC                             0.0
# 4      2020/07/25  1400 UTC                             NaN
# ...           ...       ...                             ...
# 99995  2020/08/22  0300 UTC                             NaN
# 99996  2020/08/03  1900 UTC                             NaN
# 99997  2021/08/13  2200 UTC                             NaN
# 99998  2022/10/28  2100 UTC                             6.4
# 99999  2022/07/13  0700 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  925.4
# 1                                                  944.1
# 2                                                  899.4
# ...

# %%
df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'].describe()
#descrição dos dados a serem utilizados do daframe
# Out:
# count    71889.000000
# mean        21.178566
# std          7.655026
# min        -50.900000
# 25%         17.800000
# 50%         21.400000
# 75%         25.400000
# max         42.900000
# Name: TEMPERATURA DO AR - BULBO SECO. HORARIA (C), dtype: float64

# %%
df['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'].mean()
#media da temperatura do ar
# Out:
# 21.178565566359246

# %%
df = df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])
df.shape
#retirar nulos da coluna Radiação Global
# Out:
# (41556, 27)

# %%
df[3:3]
df.columns
df[['ALTITUDE', 'ESTACAO' , 'VENTO. VELOCIDADE HORARIA (m/s)']]
#reduzindo para 3 colunas
# Out:
#        ALTITUDE                 ESTACAO  VENTO. VELOCIDADE HORARIA (m/s)
# 0        891.00       BRAGANCA PAULISTA                              2.8
# 2       1002.74                  FRANCA                              0.7
# 3        381.90              VALPARAISO                              2.2
# 7         24.00           SAO SEBASTIAO                              4.8
# 8        771.00  SAO PAULO - INTERLAGOS                              1.4
# ...         ...                     ...                              ...
# 99988    660.00                 MARILIA                              NaN
# 99990   1285.00               CRIOSFERA                             10.0
# 99991    540.41              PRADOPOLIS                              1.3
# 99992    498.00                    TUPA                              NaN
# 99998    460.65                    LINS                              0.1
#
# [41556 rows x 3 columns]

# %%
df_normalizado = df.copy()
coluna = "TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)"
df_normalizado [coluna]
#normalizando coluna
# Out:
# 0         8.0
# 2        31.6
# 3        27.5
# 7        21.1
# 8        22.6
#          ...
# 99988    25.4
# 99990   -46.5
# 99991    29.2
# 99992    33.0
# 99998    28.5
# Name: TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C), Length: 41556, dtype: float64
