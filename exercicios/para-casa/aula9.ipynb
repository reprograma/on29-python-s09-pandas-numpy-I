# %% [markdown]
# <a href="https://colab.research.google.com/github/carlitapereira/on29-python-s09-pandas-numpy-I/blob/main/exercicios/para-casa/aula9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
