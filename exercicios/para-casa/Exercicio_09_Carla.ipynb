# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_MG.csv', sep=";", encoding='latin-1', on_bad_lines='skip')

# %%
df.head()
# Out:
#          Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0  2022/09/08  2200 UTC                             0.0
# 1  2021/01/26  1100 UTC                             0.0
# 2  2021/11/24  2100 UTC                             0.0
# 3  2021/07/25  1800 UTC                             0.0
# 4  2020/07/16  0700 UTC                             0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                              909.4
# 1                                              926.5
# 2                                              924.5
# 3                                              929.2
# 4                                              928.6
#
#    PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            909.4
# 1                                            926.5
# 2                                            924.5
# 3                                            930.1
# ...

# %% [markdown]
# df[['PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)','RADIACAO GLOBAL (Kj/m2)']].mean()

# %%
df[['TEMPERATURA DO AR - BULBO SECO. HORARIA (C)']].mean()
# Out:
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)    21.880183
# dtype: float64

# %%
df.dropna(subset=['RADIACAO GLOBAL (Kj/m2)'])
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 1      2021/01/26  1100 UTC                             0.0
# 2      2021/11/24  2100 UTC                             0.0
# 3      2021/07/25  1800 UTC                             0.0
# 5      2022/09/29  1400 UTC                             0.0
# 6      2021/04/30  1900 UTC                             0.0
# ...           ...       ...                             ...
# 40609  2020/08/08  1300 UTC                             0.0
# 40612  2022/11/28  1300 UTC                             0.0
# 40615  2021/03/25  1100 UTC                             NaN
# 40620  2020/02/08  1900 UTC                             0.0
# 40621  2020/06/17  2100 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 1                                                  926.5
# 2                                                  924.5
# 3                                                  929.2
# ...

# %%
df[['Data','PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)','RADIACAO GLOBAL (Kj/m2)']].sample(3)
# Out:
#              Data  PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 37481  2022/04/06                                            959.3
# 25651  2020/04/03                                            947.8
# 35386  2020/04/20                                            930.3
#
#        RADIACAO GLOBAL (Kj/m2)
# 37481                   2600.2
# 25651                      NaN
# 35386                      0.0
