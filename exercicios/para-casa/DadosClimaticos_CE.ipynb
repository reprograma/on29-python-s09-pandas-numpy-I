# %% [markdown]
# <a href="https://colab.research.google.com/github/chaves08r/on29-python-s09-pandas-numpy-I/blob/main/DadosClimaticos_CE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Utilizar a tabela de dados do clima de seu estado, manipule os dados de acordo com as instruções abaixo: - calcular a média da temperatura da amostra - retirar nulos da coluna 'RADIACAO GLOBAL (Kj/m2)' - copiar o dataframe reduzindo para 3 colunas (a sua escolha) e 1000 linhas (aleatórias) - Bônus: normalizar coluna (qualquer uma) - Bônus II: pesquisar sobre outras formas de processamento de dados além das vistas em sala de aula

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_CE.csv', sep=';' , encoding='latin-1', on_bad_lines='skip')

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2021/05/10  1600 UTC                             NaN
# 1      2022/01/06  0500 UTC                             NaN
# 2      2020/12/30  2000 UTC                             NaN
# 3      2022/10/15  0800 UTC                             NaN
# 4      2021/04/03  1600 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/04/25  2200 UTC                             NaN
# 99996  2021/01/15  0200 UTC                             NaN
# 99997  2022/12/16  0400 UTC                             0.0
# 99998  2022/08/12  1500 UTC                             0.0
# 99999  2022/07/15  1900 UTC                             NaN
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
media_temperatura = df['TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)'].mean()
print("Média da temperatura da amostra:", media_temperatura)
# Out:
# Média da temperatura da amostra: 27.640851974740446

# %%
df.dropna()
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 4      2021/04/03  1600 UTC                             0.0
# 8      2021/03/27  1900 UTC                             0.0
# 13     2021/06/05  1500 UTC                             0.0
# 14     2020/11/01  1500 UTC                             0.0
# 16     2021/04/28  2100 UTC                             0.0
# ...           ...       ...                             ...
# 99991  2020/11/25  1800 UTC                             0.0
# 99993  2020/07/16  2100 UTC                             0.0
# 99994  2021/06/02  1100 UTC                             0.0
# 99997  2022/12/16  0400 UTC                             0.0
# 99998  2022/08/12  1500 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 4                                                  977.0
# 8                                                 1004.9
# 13                                                 988.3
# ...

# %%
df.loc[:,['PRECIPITAO TOTAL. HORARIO (mm)', 'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)', 'ESTACAO']]
# Out:
#        PRECIPITAO TOTAL. HORARIO (mm)  \
# 32753                             0.0
# 10688                             0.0
# 33048                             NaN
# 5336                              NaN
# 24971                             NaN
# ...                               ...
# 51246                             NaN
# 59315                             0.0
# 7119                              0.0
# 52094                             NaN
# 72977                             0.0
#
#        TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)       ESTACAO
# 32753                                       28.5   MORADA NOVA
# 10688                                       23.3      BARBALHA
# 33048                                       25.4    JAGUARUANA
# 5336                                         NaN     ITAPIPOCA
# 24971                                        NaN  QUIXERAMOBIM
# ...                                          ...           ...
# ...

# %%
df_normalizado = df.copy()

coluna = "TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)"

df_normalizado[coluna] = (df_normalizado[coluna] - df_normalizado[coluna].min()) / (df_normalizado[coluna].max() - df_normalizado[coluna].min())

df_normalizado[coluna]
# Out:
# 32753    0.490291
# 10688    0.237864
# 33048    0.339806
# 5336          NaN
# 24971         NaN
#            ...
# 51246         NaN
# 59315    0.553398
# 7119     0.572816
# 52094         NaN
# 72977    0.553398
# Name: TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C), Length: 1000, dtype: float64
