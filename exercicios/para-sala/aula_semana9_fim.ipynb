# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_.csv', sep=';')

# %%
df
# Out:
#              Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0      2022/02/06  2300 UTC                             1.0
# 1      2022/06/14  1700 UTC                             NaN
# 2      2021/07/20  0200 UTC                             NaN
# 3      2022/01/08  0900 UTC                             NaN
# 4      2021/03/13  2200 UTC                             0.0
# ...           ...       ...                             ...
# 99995  2020/09/02  0000 UTC                             0.0
# 99996  2020/11/24  1800 UTC                             NaN
# 99997  2022/09/10  0900 UTC                             0.0
# 99998  2020/09/30  2100 UTC                             0.0
# 99999  2020/05/31  1300 UTC                             0.0
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                  898.3
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
df.shape
# Out:
# (100000, 27)

# %%
df.describe()
# Out:
#        PRECIPITAO TOTAL. HORARIO (mm)  \
# count                    61239.000000
# mean                         0.167028
# std                          1.388695
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                         63.000000
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# count                                       67568.000000
# mean                                          961.650192
# std                                            39.683310
# min                                           720.600000
# 25%                                           933.200000
# 50%                                           966.100000
# 75%                                           993.700000
# max                                          1032.300000
#
#        PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# ...

# %%
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAO TOTAL. HORARIO (mm)                           float64
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)    float64
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          float64
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         float64
# RADIACAO GLOBAL (Kj/m2)                                  float64
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)              float64
# TEMPERATURA DO PONTO DE ORVALHO (C)                      float64
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                float64
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                float64
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)          float64
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)          float64
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# ...

# %%
df_ultimos = df.tail(100)

# %%
df_ultimos = df_ultimos.reset_index(drop=True)

# %%
df_menor = df.sample(250)

# %%
df_menor = df_menor.reset_index(drop=True)

# %%
df_menor
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0    2021/05/23  0900 UTC                             0.0
# 1    2020/07/11  1900 UTC                             NaN
# 2    2021/07/28  1600 UTC                             0.0
# 3    2021/10/05  1300 UTC                             NaN
# 4    2020/10/14  2100 UTC                             NaN
# ..          ...       ...                             ...
# 245  2022/03/02  0300 UTC                             NaN
# 246  2022/03/25  0700 UTC                             NaN
# 247  2021/08/30  0900 UTC                             NaN
# 248  2022/02/22  2100 UTC                             NaN
# 249  2022/05/22  0000 UTC                             0.0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                962.4
# 1                                                  NaN
# 2                                               1002.0
# ...

# %%
df_ultimos = df.tail(100)

# %%
df_ultimos = df_ultimos.reset_index(drop=True)

# %%
df_ultimos
# Out:
#           Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0   2021/05/03  2300 UTC                             0.0
# 1   2020/05/02  2200 UTC                             0.0
# 2   2022/02/11  1200 UTC                             0.0
# 3   2020/12/30  0000 UTC                             NaN
# 4   2020/10/27  1200 UTC                             0.0
# ..         ...       ...                             ...
# 95  2020/09/02  0000 UTC                             0.0
# 96  2020/11/24  1800 UTC                             NaN
# 97  2022/09/10  0900 UTC                             0.0
# 98  2020/09/30  2100 UTC                             0.0
# 99  2020/05/31  1300 UTC                             0.0
#
#     PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                               946.3
# 1                                               951.6
# 2                                               915.6
# 3                                                 NaN
# ...

# %%
df[['PRECIPITAO TOTAL. HORARIO (mm)','RADIACAO GLOBAL (Kj/m2)']].describe()
# Out:
#        PRECIPITAO TOTAL. HORARIO (mm)  RADIACAO GLOBAL (Kj/m2)
# count                    61239.000000             39661.000000
# mean                         0.167028              1315.574423
# std                          1.388695              1127.231172
# min                          0.000000                 0.000000
# 25%                          0.000000               213.700000
# 50%                          0.000000              1132.400000
# 75%                          0.000000              2237.900000
# max                         63.000000              8647.100000

# %%
df['PRECIPITAO TOTAL. HORARIO (mm)'].describe()
# Out:
# count    61239.000000
# mean         0.167028
# std          1.388695
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         63.000000
# Name: PRECIPITAO TOTAL. HORARIO (mm), dtype: float64
