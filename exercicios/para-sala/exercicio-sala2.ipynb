# %% [markdown]
# <a href="https://colab.research.google.com/github/LaryssaCunha/on29-python-s09-pandas-numpy-I/blob/main/exercicios/para-sala/exercicio-sala2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample_1000.csv', sep=';')

# %%
df
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0    2020/03/13  2100 UTC                             0.0
# 1    2021/05/01  2300 UTC                             0.0
# 2    2021/10/06  1100 UTC                             NaN
# 3    2020/05/29  0000 UTC                             0.0
# 4    2021/03/22  0200 UTC                             NaN
# ..          ...       ...                             ...
# 995  2020/02/27  1300 UTC                             0.0
# 996  2022/05/27  0300 UTC                             0.0
# 997  2022/02/12  1500 UTC                             NaN
# 998  2022/06/15  0200 UTC                             0.0
# 999  2020/08/18  1600 UTC                             NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                               1009.4
# 1                                                992.0
# 2                                                  NaN
# ...

# %%
df.head() #inicio da tabela. vai  vir 5 por padrao ja que nao tem nada inserido.
# Out:
#          Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0  2020/03/13  2100 UTC                             0.0
# 1  2021/05/01  2300 UTC                             0.0
# 2  2021/10/06  1100 UTC                             NaN
# 3  2020/05/29  0000 UTC                             0.0
# 4  2021/03/22  0200 UTC                             NaN
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                             1009.4
# 1                                              992.0
# 2                                                NaN
# 3                                              993.0
# 4                                                NaN
#
#    PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           1009.4
# 1                                            992.0
# 2                                              NaN
# 3                                            993.0
# ...

# %%
df.tail(10) #pedi os dez últimos. tail é o final, "cauda em ingles"
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 990  2022/06/23  1200 UTC                             NaN
# 991  2020/02/04  2300 UTC                             0.0
# 992  2020/07/30  1000 UTC                             0.0
# 993  2020/02/01  0400 UTC                             0.0
# 994  2021/09/25  2100 UTC                             0.0
# 995  2020/02/27  1300 UTC                             0.0
# 996  2022/05/27  0300 UTC                             0.0
# 997  2022/02/12  1500 UTC                             NaN
# 998  2022/06/15  0200 UTC                             0.0
# 999  2020/08/18  1600 UTC                             NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 990                                                NaN
# 991                                              978.9
# 992                                              994.1
# 993                                              975.7
# ...

# %%
df.shape #retorna a quantidade de registros que tem. 1000 linhas e 27 colunas
# Out:
# (1000, 27)

# %%
df.describe() #descreve as informações da tabela. "a moda ", media, minima, maximo.. dados estatisticos
# Out:
#        PRECIPITAO TOTAL. HORARIO (mm)  \
# count                      595.000000
# mean                         0.224874
# std                          1.651992
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                         25.800000
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# count                                         657.000000
# mean                                          963.157078
# std                                            39.033726
# min                                           759.300000
# 25%                                           934.000000
# 50%                                           967.900000
# 75%                                           993.000000
# max                                          1026.300000
#
#        PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# ...

# %%
df.dtypes #retorna quais os tipos de dados são os de cada coluna
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAO TOTAL. HORARIO (mm)                           float64
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)    float64
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          float64
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         float64
# RADIACAO GLOBAL (Kj/m2)                                  float64
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)              float64
# TEMPERATURA DO PONTO DE ORVALHO (C)                      float64
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                float64
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                float64
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)          float64
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)          float64
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# ...

# %%
df_menor = df.sample(250) #retorna uma amostra aleatória e sem estar necessariamente na ordem

# %%
df_menor
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 795  2020/08/01  1700 UTC                             0.0
# 649  2020/07/27  1100 UTC                             0.0
# 509  2022/02/20  1700 UTC                             0.0
# 645  2021/06/22  2100 UTC                             NaN
# 966  2021/04/01  0000 UTC                             NaN
# ..          ...       ...                             ...
# 411  2020/09/27  1700 UTC                             0.0
# 929  2020/03/01  1500 UTC                             NaN
# 186  2021/04/29  2000 UTC                             0.0
# 679  2022/01/07  1600 UTC                             0.4
# 467  2020/09/27  1100 UTC                             0.0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 795                                              958.5
# 649                                              917.3
# 509                                              990.3
# ...

# %%
df_menor = df_menor.reset_index(drop=True) #retorna ordenado

# %%
df_menor
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0    2020/08/01  1700 UTC                             0.0
# 1    2020/07/27  1100 UTC                             0.0
# 2    2022/02/20  1700 UTC                             0.0
# 3    2021/06/22  2100 UTC                             NaN
# 4    2021/04/01  0000 UTC                             NaN
# ..          ...       ...                             ...
# 245  2020/09/27  1700 UTC                             0.0
# 246  2020/03/01  1500 UTC                             NaN
# 247  2021/04/29  2000 UTC                             0.0
# 248  2022/01/07  1600 UTC                             0.4
# 249  2020/09/27  1100 UTC                             0.0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                958.5
# 1                                                917.3
# 2                                                990.3
# ...

# %%
df_ultimos = df.tail(100)

# %%
df_ultimos
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 900  2022/01/23  2000 UTC                             0.0
# 901  2020/04/18  2300 UTC                             NaN
# 902  2021/09/01  1900 UTC                             0.0
# 903  2020/08/11  2300 UTC                             NaN
# 904  2022/12/07  1800 UTC                            25.8
# ..          ...       ...                             ...
# 995  2020/02/27  1300 UTC                             0.0
# 996  2022/05/27  0300 UTC                             0.0
# 997  2022/02/12  1500 UTC                             NaN
# 998  2022/06/15  0200 UTC                             0.0
# 999  2020/08/18  1600 UTC                             NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 900                                             1006.5
# 901                                              965.4
# 902                                              920.3
# ...

# %%
df_ultimos = df_ultimos.reset_index(drop=True) #retornando os ultimos com o index ordenados

# %%
df_ultimos
# Out:
#           Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0   2022/01/23  2000 UTC                             0.0
# 1   2020/04/18  2300 UTC                             NaN
# 2   2021/09/01  1900 UTC                             0.0
# 3   2020/08/11  2300 UTC                             NaN
# 4   2022/12/07  1800 UTC                            25.8
# ..         ...       ...                             ...
# 95  2020/02/27  1300 UTC                             0.0
# 96  2022/05/27  0300 UTC                             0.0
# 97  2022/02/12  1500 UTC                             NaN
# 98  2022/06/15  0200 UTC                             0.0
# 99  2020/08/18  1600 UTC                             NaN
#
#     PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                              1006.5
# 1                                               965.4
# 2                                               920.3
# 3                                                 NaN
# ...

# %%
mini_df = df[:10] #retorna só os dez primeiros registros

# %%
mini_df
# Out:
#          Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0  2020/03/13  2100 UTC                             0.0
# 1  2021/05/01  2300 UTC                             0.0
# 2  2021/10/06  1100 UTC                             NaN
# 3  2020/05/29  0000 UTC                             0.0
# 4  2021/03/22  0200 UTC                             NaN
# 5  2022/03/06  0600 UTC                             0.0
# 6  2021/05/07  0900 UTC                             NaN
# 7  2020/11/07  1600 UTC                             0.0
# 8  2020/01/17  0700 UTC                            23.2
# 9  2022/07/21  1800 UTC                             0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                             1009.4
# 1                                              992.0
# 2                                                NaN
# 3                                              993.0
# 4                                                NaN
# ...

# %%
mini_df = df[10:20] #retorna as 10 primeiras linhas e as 20 ultimas colunas

# %%
mini_df
# Out:
#           Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 10  2022/08/16  0300 UTC                             0.0
# 11  2021/01/13  1000 UTC                             0.0
# 12  2021/12/06  0200 UTC                             NaN
# 13  2022/12/29  0900 UTC                             NaN
# 14  2022/04/25  0000 UTC                             0.0
# 15  2022/04/25  1000 UTC                             NaN
# 16  2021/12/07  0200 UTC                             NaN
# 17  2021/08/09  1400 UTC                             NaN
# 18  2021/09/23  1600 UTC                             0.0
# 19  2021/08/22  1200 UTC                             0.0
#
#     PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 10                                             1013.4
# 11                                              969.9
# 12                                                NaN
# 13                                                NaN
# 14                                              904.4
# ...

# %%
df.columns #retorna as colunas
# Out:
# Index(['Data', 'Hora UTC', 'PRECIPITAO TOTAL. HORARIO (mm)',
#        'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)',
#        'PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#        'PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
#        'RADIACAO GLOBAL (Kj/m2)',
#        'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)',
#        'TEMPERATURA DO PONTO DE ORVALHO (C)',
#        'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)',
#        'TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)',
#        'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)',
#        'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)',
#        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
#        'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#        'UMIDADE RELATIVA DO AR. HORARIA (%)',
#        'VENTO. DIREAO HORARIA (gr) ((gr))', 'VENTO. RAJADA MAXIMA (m/s)',
#        'VENTO. VELOCIDADE HORARIA (m/s)', 'REGIAO', 'UF', 'ESTACAO',
#        'CODIGO (WMO)', 'LATITUDE', 'LONGITUDE', 'ALTITUDE',
# ...

# %%
df['TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)'] #seleciona a coluna
# Out:
# 0      27.1
# 1      31.8
# 2       NaN
# 3      23.8
# 4       NaN
#        ...
# 995    28.5
# 996    17.2
# 997     NaN
# 998    13.8
# 999     NaN
# Name: TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C), Length: 1000, dtype: float64

# %%
colunas = [] #usando o python, selecionando colunas e itens
colunas.append('PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)');
colunas.append('RADIACAO GLOBAL (Kj/m2)');

# %%
df[colunas].describe() #descrever
# Out:
#        PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# count                                       657.000000
# mean                                        963.432116
# std                                          39.010181
# min                                         759.300000
# 25%                                         934.000000
# 50%                                         967.900000
# 75%                                         993.500000
# max                                        1026.600000
#
#        RADIACAO GLOBAL (Kj/m2)
# count               396.000000
# mean               1276.306566
# std                1169.356682
# min                   0.000000
# 25%                 161.375000
# 50%                 966.650000
# 75%                2261.525000
# max                4376.300000

# %%
df.min() #retorna o minimo de tudo
# Out:
# Data                                                     2020/01/01
# Hora UTC                                                   0000 UTC
# PRECIPITAO TOTAL. HORARIO (mm)                                  0.0
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)         759.3
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)               759.3
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)              758.4
# RADIACAO GLOBAL (Kj/m2)                                         0.0
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)                   -32.2
# TEMPERATURA DO PONTO DE ORVALHO (C)                           -36.9
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                     -31.6
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                     -32.4
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)               -36.2
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)               -37.0
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                       16.0
# ...

# %%
df.max() #maximo
# Out:
# Data                                                     2022/12/31
# Hora UTC                                                   2300 UTC
# PRECIPITAO TOTAL. HORARIO (mm)                                 25.8
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)        1026.3
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)              1026.6
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)             1026.3
# RADIACAO GLOBAL (Kj/m2)                                      4376.3
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)                    39.5
# TEMPERATURA DO PONTO DE ORVALHO (C)                            25.3
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                      40.6
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                      39.5
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)                27.6
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)                25.2
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                      100.0
# ...

# %%
df.sum() #somar tudo
# Out:
# Data                                                     2020/03/132021/05/012021/10/062020/05/292021/0...
# Hora UTC                                                 2100 UTC2300 UTC1100 UTC0000 UTC0200 UTC0600 U...
# PRECIPITAO TOTAL. HORARIO (mm)                                                                       133.8
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)                                             632794.2
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)                                                   632974.9
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)                                                  632611.4
# RADIACAO GLOBAL (Kj/m2)                                                                           505417.4
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)                                                        14942.4
# TEMPERATURA DO PONTO DE ORVALHO (C)                                                                10512.3
# ...

# %%
df.mean(numeric_only=True) #retorna as médias do dataframe, deve pedir que seja só os numeros, se tiver string vai dar erro
# Out:
# PRECIPITAO TOTAL. HORARIO (mm)                              0.224874
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)     963.157078
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           963.432116
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          962.878843
# RADIACAO GLOBAL (Kj/m2)                                  1276.306566
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)                22.708815
# TEMPERATURA DO PONTO DE ORVALHO (C)                        16.739331
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                  23.389210
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                  22.035562
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)            17.303349
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)            16.168631
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                   75.513471
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                   69.583201
# UMIDADE RELATIVA DO AR. HORARIA (%)                        72.622222
# ...

# %%
df.isnull()
# Out:
#       Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0    False     False                           False
# 1    False     False                           False
# 2    False     False                            True
# 3    False     False                           False
# 4    False     False                            True
# ..     ...       ...                             ...
# 995  False     False                           False
# 996  False     False                           False
# 997  False     False                            True
# 998  False     False                           False
# 999  False     False                            True
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                False
# 1                                                False
# 2                                                 True
# 3                                                False
# ...

# %%
df.isnull().sum() #retorna quantos registros sao nulos e soma eles
# Out:
# Data                                                       0
# Hora UTC                                                   0
# PRECIPITAO TOTAL. HORARIO (mm)                           405
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)    343
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          343
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         343
# RADIACAO GLOBAL (Kj/m2)                                  604
# TEMPERATURA DO AR - BULBO SECO. HORARIA (C)              342
# TEMPERATURA DO PONTO DE ORVALHO (C)                      372
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (C)                342
# TEMPERATURA MINIMA NA HORA ANT. (AUT) (C)                342
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (C)          373
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (C)          372
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 369
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 369
# ...

# %%
df.dropna() #deleta a linha toda que tem algum not a number
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0    2020/03/13  2100 UTC                             0.0
# 5    2022/03/06  0600 UTC                             0.0
# 7    2020/11/07  1600 UTC                             0.0
# 11   2021/01/13  1000 UTC                             0.0
# 18   2021/09/23  1600 UTC                             0.0
# ..          ...       ...                             ...
# 978  2022/12/01  1400 UTC                             0.0
# 989  2022/10/24  1200 UTC                             0.0
# 992  2020/07/30  1000 UTC                             0.0
# 994  2021/09/25  2100 UTC                             0.0
# 995  2020/02/27  1300 UTC                             0.0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                               1009.4
# 5                                               1013.3
# 7                                                992.4
# ...

# %%
df.dropna(subset=['PRECIPITAO TOTAL. HORARIO (mm)', 'VENTO. VELOCIDADE HORARIA (m/s)']) #seleciona as linhas que quer que seja deletada)
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0    2020/03/13  2100 UTC                             0.0
# 1    2021/05/01  2300 UTC                             0.0
# 3    2020/05/29  0000 UTC                             0.0
# 5    2022/03/06  0600 UTC                             0.0
# 7    2020/11/07  1600 UTC                             0.0
# ..          ...       ...                             ...
# 993  2020/02/01  0400 UTC                             0.0
# 994  2021/09/25  2100 UTC                             0.0
# 995  2020/02/27  1300 UTC                             0.0
# 996  2022/05/27  0300 UTC                             0.0
# 998  2022/06/15  0200 UTC                             0.0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                               1009.4
# 1                                                992.0
# 3                                                993.0
# ...

# %%
df['RADIACAO GLOBAL (Kj/m2)'].fillna(df['RADIACAO GLOBAL (Kj/m2)'].mean()) #substituir uma informação
# Out:
# 0       326.600000
# 1      1276.306566
# 2      1276.306566
# 3      1276.306566
# 4      1276.306566
#           ...
# 995    2342.200000
# 996    1276.306566
# 997    1276.306566
# 998    1276.306566
# 999    1276.306566
# Name: RADIACAO GLOBAL (Kj/m2), Length: 1000, dtype: float64

# %%
df['REGIAO'].replace({'CO': 'Centro-Oeste', 'N': 'Norte', 'NE': 'Nordeste', 'S': 'Sul', 'SE': 'Sudeste'})
# Out:
# 0           Sudeste
# 1      Centro-Oeste
# 2      Centro-Oeste
# 3             Norte
# 4               Sul
#            ...
# 995        Nordeste
# 996         Sudeste
# 997        Nordeste
# 998         Sudeste
# 999        Nordeste
# Name: REGIAO, Length: 1000, dtype: object

# %%
df.drop_duplicates() #deleta os dados duplicados
# Out:
#            Data  Hora UTC  PRECIPITAO TOTAL. HORARIO (mm)  \
# 0    2020/03/13  2100 UTC                             0.0
# 1    2021/05/01  2300 UTC                             0.0
# 2    2021/10/06  1100 UTC                             NaN
# 3    2020/05/29  0000 UTC                             0.0
# 4    2021/03/22  0200 UTC                             NaN
# ..          ...       ...                             ...
# 995  2020/02/27  1300 UTC                             0.0
# 996  2022/05/27  0300 UTC                             0.0
# 997  2022/02/12  1500 UTC                             NaN
# 998  2022/06/15  0200 UTC                             0.0
# 999  2020/08/18  1600 UTC                             NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                               1009.4
# 1                                                992.0
# 2                                                  NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
df[['PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)', 'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)']].plot()
# Out:
# <Axes: >

# %%
#normalização dos dados para poder fazer uma comparação melhor
coluna = 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)'

df[coluna] = (df[coluna] - df[coluna].min())/(df[coluna].max() - df[coluna].min())

# %%
coluna = 'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)'

df[coluna] = (df[coluna] - df[coluna].min())/(df[coluna].max() - df[coluna].min())

# %%
df[['PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)', 'TEMPERATURA DO AR - BULBO SECO. HORARIA (C)']].plot()

plt.show()
